# %% [markdown]
# ## 100 Practice Exerciese for Titanic Dataset

# %% [markdown]
# 1.	Load the 2 Titanic datasets into a pandas DataFrames.
#     1a. Concatenate them and save as a NEW complete Dataset.
# 2.	Display the first few rows of the dataset.
# 3.	Check the shape of the dataset (number of rows and columns).
# 4.	Identify the columns in the dataset and their data types.
# 5.	Display the summary statistics of the dataset.
# 6.	Are there any missing values in the dataset? If yes, how many and in which columns?
# 7.	Visualize the missing values using a heatmap.
# 8.	Remove the rows with missing values. How many rows are left?
# 9.	Replace the missing values in the 'Age' column with the mean age.
# 10.	Replace the missing values in the 'Cabin' column with 'Unknown'.
# 11.	Replace the missing values in the 'Embarked' column with the mode.
# 12.	Count the number of survivors and non-survivors.
# 13.	Calculate the survival rate.
# 14.	Visualize the distribution of the 'Survived' variable.
# 15.	How many males and females were on board?
# 16.	Calculate the percentage of males and females.
# 17.	Visualize the gender distribution.
# 18.	Calculate the average age of passengers.
# 19.	Visualize the age distribution using a histogram.
# 20.	Calculate the average age for each gender.
# 21.	Visualize the age distribution for each gender.
# 22.	Calculate the correlation between 'Age' and 'Fare'.
# 23.	Visualize the correlation between 'Age' and 'Fare' using a scatter plot.
# 24.	Calculate the correlation matrix for all numerical variables.
# 25.	Visualize the correlation matrix using a heatmap.
# 26.	How many passengers traveled in each passenger class ('Pclass')?
# 27.	Visualize the passenger class distribution.
# 28.	Calculate the survival rate for each passenger class.
# 29.	Visualize the survival rate for each passenger class.
# 30.	Calculate the average fare for each passenger class.
# 31.	Visualize the average fare for each passenger class.
# 32.	Identify the top 5 most common names among the passengers.
# 33.	Create a new column called 'Title' by extracting the titles from the 'Name' column.
# 34.	Calculate the count of each title.
# 35.	Visualize the distribution of titles.
# 36.	Calculate the survival rate for each title.
# 37.	Visualize the survival rate for each title.
# 38.	Calculate the average age for each title.
# 39.	Visualize the average age for each title.
# 40.	Calculate the survival rate for different age groups (e.g., children, adults, seniors).
# 41.	Visualize the survival rate for different age groups.
# 42.	Calculate the survival rate for different fare ranges (e.g., low, medium, high).
# 43.	Visualize the survival rate for different fare ranges.
# 44.	Calculate the survival rate for passengers traveling alone versus those traveling with family.
# 45.	Visualize the survival rate for passengers traveling alone versus those traveling with family.
# 46.	Calculate the survival rate for passengers with known cabin numbers versus those with unknown cabins.
# 47.	Visualize the survival rate for passengers with known cabin numbers versus those with unknown cabins.
# 48.	Identify the most common port of embarkation ('Embarked').
# 49.	Calculate the survival rate for each port of embarkation.
# 50.	Visualize the survival rate for each port of embarkation.
# 51.	Calculate the survival rate for different ticket types (e.g., numeric, alphanumeric).
# 52.	Visualize the survival rate for different ticket types.
# 53.	Identify the passengers with the highest fares.
# 54.	Calculate the survival rate for passengers with the highest fares.
# 55.	Visualize the survival rate for passengers with the highest fares.
# 56.	Identify the passengers with the lowest fares.
# 57.	Calculate the survival rate for passengers with the lowest fares.
# 58.	Visualize the survival rate for passengers with the lowest fares.
# 59.	Calculate the survival rate for passengers with siblings or spouses on board.
# 60.	Visualize the survival rate for passengers with siblings or spouses on board.
# 61.	Calculate the survival rate for passengers with parents or children on board.
# 62.	Visualize the survival rate for passengers with parents or children on board.
# 63.	Identify the passengers who paid the highest fare in each passenger class.
# 64.	Calculate the survival rate for passengers who paid the highest fare in each passenger class.
# 65.	Visualize the survival rate for passengers who paid the highest fare in each passenger class.
# 66.	Identify the passengers who paid the lowest fare in each passenger class.
# 67.	Calculate the survival rate for passengers who paid the lowest fare in each passenger class.
# 68.	Visualize the survival rate for passengers who paid the lowest fare in each passenger class.
# 69.	Calculate the average fare for male and female passengers.
# 70.	Visualize the average fare for male and female passengers.
# 71.	Calculate the survival rate for male and female passengers.
# 72.	Visualize the survival rate for male and female passengers.
# 73.	Calculate the survival rate for passengers with different numbers of siblings or spouses.
# 74.	Visualize the survival rate for passengers with different numbers of siblings or spouses.
# 75.	Calculate the survival rate for passengers with different numbers of parents or children.
# 76.	Visualize the survival rate for passengers with different numbers of parents or children.
# 77.	Calculate the survival rate for passengers traveling in different family sizes (e.g., alone, small family, large family).
# 78.	Visualize the survival rate for passengers traveling in different family sizes.
# 79.	Identify the passengers who had the highest number of siblings or spouses.
# 80.	Calculate the survival rate for passengers who had the highest number of siblings or spouses.
# 81.	Visualize the survival rate for passengers who had the highest number of siblings or spouses.
# 82.	Identify the passengers who had the highest number of parents or children.
# 83.	Calculate the survival rate for passengers who had the highest number of parents or children.
# 84.	Visualize the survival rate for passengers who had the highest number of parents or children.
# 85.	Identify the passengers with the highest number of family members on board.
# 86.	Calculate the survival rate for passengers with the highest number of family members on board.
# 87.	Visualize the survival rate for passengers with the highest number of family members on board.
# 88.	Identify the passengers who had the lowest number of siblings or spouses.
# 89.	Calculate the survival rate for passengers who had the lowest number of siblings or spouses.
# 90.	Visualize the survival rate for passengers who had the lowest number of siblings or spouses.
# 91.	Identify the passengers who had the lowest number of parents or children.
# 92.	Calculate the survival rate for passengers who had the lowest number of parents or children.
# 93.	Visualize the survival rate for passengers who had the lowest number of parents or children.
# 94.	Identify the passengers with the lowest number of family members on board.
# 95.	Calculate the survival rate for passengers with the lowest number of family members on board.
# 96.	Visualize the survival rate for passengers with the lowest number of family members on board.
# 97.	Identify any outliers in the 'Age' and 'Fare' columns.
# 98.	Visualize the distribution of 'Age' and 'Fare' with boxplots.
# 99.	Calculate the survival rate for passengers with different ticket fare ranges.
# 100. Visualize the survival rate for passengers with different ticket fare ranges.
